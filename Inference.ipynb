# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.3/137.3 kB 4.4 MB/s eta 0:00:00

# %%
from groq import Groq

client = Groq(api_key=os.environ["GROQ_API_KEY"])

# %%
import torch
import json
from transformers import XLMRobertaTokenizerFast, XLMRobertaForTokenClassification
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

MODEL_PATH = "/content/drive/MyDrive/NER_RETRAIN/xlmr_location_ner"

tokenizer = XLMRobertaTokenizerFast.from_pretrained(MODEL_PATH)
model = XLMRobertaForTokenClassification.from_pretrained(MODEL_PATH)
model.eval()
model.to(DEVICE) # Move the model to the correct device

with open("/content/drive/MyDrive/NER_RETRAIN/id2tag.json") as f:
    id2tag = {int(k):v for k,v in json.load(f).items()}

def extract_locations(text):
    toks = tokenizer(text, return_tensors="pt")
    toks = {k: v.to(DEVICE) for k, v in toks.items()} # Move input tensors to the correct device
    with torch.no_grad():
        logits = model(**toks).logits[0]

    preds = torch.argmax(logits, dim=-1).tolist()
    tokens = tokenizer.convert_ids_to_tokens(toks["input_ids"][0])

    locations = []
    buf = ""

    for tok, p in zip(tokens, preds):
        label = id2tag[p]
        tok = tok.replace(" ", "")

        if label == "B-LOC":
            if buf:
                locations.append(buf)
            buf = tok
        elif label == "I-LOC":
            buf += " " + tok
        else:
            if buf:
                locations.append(buf)
                buf = ""

    if buf:
        locations.append(buf)

    return list(set(locations))

# %%
def analyze_incident_with_llm(text, locations):
    prompt = f"""
You are an AI incident-analysis engine for Indian news.

Given a news text and a list of detected locations, extract:

1. classification: "GOOD", "BAD", or "NEUTRAL"
2. event_type: (accident, crime, political, natural disaster, achievement, other)
3. severity: low / medium / high
4. deaths: number of deaths if mentioned
5. injured: number injured
6. main_incident_location: which location is the event-site
7. other_locations: everything else
8. summary: one sentence summary

TEXT: {text}
LOCATIONS: {locations}

Return ONLY valid JSON.
"""

    response = client.chat.completions.create(
        model="llama-3.1-8b-instant", # Changed to a valid model
        messages=[{"role": "user", "content": prompt}],
        temperature=0.1
    )

    return response.choices[0].message.content

# %%
import pandas as pd
india_df = pd.read_excel("/content/drive/MyDrive/NER_RETRAIN/India District (1).xlsx")

def lookup_location_info(location):
    # Try district match
    row = india_df[india_df["District Name"].str.lower() == location.lower()]
    if not row.empty:
        r = row.iloc[0]
        return {
            "district": r["District Name"],
            "state": r["State Name"],
            "district_code": int(r["District Code"]),
            "state_code": int(r["State Code"])
        }

    # Try state match
    row = india_df[india_df["State Name"].str.lower() == location.lower()]
    if not row.empty:
        r = row.iloc[0]
        return {
            "district": None,
            "state": r["State Name"],
            "district_code": None,
            "state_code": int(r["State Code"])
        }

    return None

# %%
import re
import json

def extract_json(text):
    """
    Extract the first valid JSON object from any LLM output.
    """

    # Find JSON block with regex
    match = re.search(r"\{[\s\S]*\}", text)

    if match:
        json_str = match.group(0)

        # Try to load JSON
        try:
            return json.loads(json_str)
        except:
            pass

    # If still failing, try fixing common issues:
    text = text.strip()

    # Remove markdown fences
    text = text.replace("```json", "").replace("```", "")

    # Attempt direct load
    try:
        return json.loads(text)
    except:
        raise ValueError("❌ Could not parse JSON from LLM output:\n" + text)


def extract_full_incident(text):
    # Step 1: Location detection
    locations = extract_locations(text)

    # Step 2: LLM incident analysis
    llm_json = analyze_incident_with_llm(text, locations)

    # Step 3: Robust JSON extraction
    data = extract_json(llm_json)

    # Step 4: Excel mapping for main incident location
    main_loc = data.get("main_incident_location")
    if main_loc:
        data["location_details"] = lookup_location_info(main_loc)

    return data

# %%
text = "Chennai and Bangalore have a water war and 3 people died in Dindigul."

result = extract_full_incident(text)
result
# Out:
# {'classification': 'BAD',
#  'event_type': 'accident',
#  'severity': 'high',
#  'deaths': 3,
#  'injured': None,
#  'main_incident_location': 'Dindigul',
#  'other_locations': ['Chennai', 'Bangalore'],
#  'summary': 'A water war in Chennai and Bangalore resulted in 3 deaths in Dindigul.',
#  'location_details': {'district': 'Dindigul',
#   'state': 'TAMIL NADU',
#   'district_code': 612,
#   'state_code': 33}}

# %%
# !pip install newspaper3k
# Out:
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (4.13.5)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (11.3.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (6.0.3)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (5.4.0)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (3.9.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (2.32.4)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 61.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (2.9.0.post0)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (4.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.17.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (2025.10.5)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-3.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.12/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.20.0)
# Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 14.8 MB/s eta 0:00:00
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.1 MB/s eta 0:00:00
# Downloading tldextract-5.3.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 7.2 MB/s eta 0:00:00
# Downloading requests_file-3.0.1-py2.py3-none-any.whl (4.5 kB)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13540 sha256=a47d6abe1cd964e57cf02024d33e2dba4371848a72364046462d2f59436e3476
#   Stored in directory: /root/.cache/pip/wheels/a5/91/9f/00d66475960891a64867914273fcaf78df6cb04d905b104a2a
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3341 sha256=a71dcff0c012ae91fc6070810175fd92dfbd0798cad5bd5871e4f786c9ef9314
#   Stored in directory: /root/.cache/pip/wheels/9f/9f/fb/364871d7426d3cdd4d293dcf7e53d97f160c508b2ccf00cc79
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398380 sha256=6d7cf096fe068a88ed61a8a398861265664368648d7d35e475031c9e6c02be0e
#   Stored in directory: /root/.cache/pip/wheels/26/72/f7/fff392a8d4ea988dea4ccf9788599d09462a7f5e51e04f8a92
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=f8ee447c7124b1d39bd1d23b422e8b8f2cc80c401f868779bbc50e511c2aa87d
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.3.0 feedfinder2-0.0.4 feedparser-6.0.12 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-3.0.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.3.0

# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 3.0 MB/s eta 0:00:00
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=04413f9813db9b2bb973cb7a941e177976faddf13e0cb6e67f5891fda8cd21ef
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.12 sgmllib3k-1.0.0

# %%
import feedparser

def fetch_rss_articles(feed_url, limit=10):
    feed = feedparser.parse(feed_url)
    articles = []

    for entry in feed.entries[:limit]:
        title = entry.title
        summary = entry.summary if "summary" in entry else ""
        link = entry.link

        text = title + "\n\n" + summary
        articles.append({"title": title, "link": link, "text": text})

    return articles

# %%
rss_feeds = [
    "https://feeds.feedburner.com/ndtvnews-india-news",
    "https://www.hindustantimes.com/feeds/rss/india-news/rssfeed.xml",
    "https://timesofindia.indiatimes.com/rssfeeds/296589292.cms",
    "https://www.indiatoday.in/rss/1206614",
    "https://indianexpress.com/section/india/feed/"
]

all_articles = []

for feed in rss_feeds:
    try:
        print("📡 Fetching:", feed)
        articles = fetch_rss_articles(feed, limit=5)
        all_articles.extend(articles)
    except Exception as e:
        print("❌ RSS Error:", e)

len(all_articles)
# Out:
# 📡 Fetching: https://feeds.feedburner.com/ndtvnews-india-news
# 📡 Fetching: https://www.hindustantimes.com/feeds/rss/india-news/rssfeed.xml
# 📡 Fetching: https://timesofindia.indiatimes.com/rssfeeds/296589292.cms
# 📡 Fetching: https://www.indiatoday.in/rss/1206614
# 📡 Fetching: https://indianexpress.com/section/india/feed/
# 25

# %%
results = []

for article in all_articles:
    print("\n📰 Analyzing:", article["title"])
    incident = extract_full_incident(article["text"])

    results.append({
        "title": article["title"],
        "link": article["link"],
        "incident": incident
    })
# Out:
# 📰 Analyzing: Jaipur Girl Begged Teacher For Help "For 45 Minutes" Before Suicide: Report
#
# 📰 Analyzing: 'Very Intense Earthquake, Building Shook For 30 Seconds': Kolkata Residents On Tremors
#
# 📰 Analyzing: 5.7-Magnitude Earthquake Hits Bangladesh, Tremors Felt In Kolkata
#
# 📰 Analyzing: "Stand And Greet": New SOP For Maharashtra Officials To Welcome Politicians
#
# 📰 Analyzing: Over 200 Al Falah University Doctors, Staff Under Scanner After Delhi Blast
#
# 📰 Analyzing: ‘Emotionally exhausting’: Al Falah University students' kin unsure of next steps amid terror probe
#
# 📰 Analyzing: Himachal man who lost his memory reunited with family after 45 years
#
# 📰 Analyzing: Haryana man kills sister for marrying against family's wishes, held before attacking her husband
#
# 📰 Analyzing: Kolkata earthquake: Chandelier, light, water bottle shake as tremors jolt city
#
# 📰 Analyzing: ‘Bollywood-style beating’: Assam CM after police seize drug contraband
#
# 📰 Analyzing: 'He’s frank': White House defends Trump’s 'Piggy' remark on female reporter; asks media to appreciate his 'candour'
#
# 📰 Analyzing: UAE named as world 3rd largest humanitarian donor in 2025 with $1.46 billion in global relief
#
# 📰 Analyzing: India expands visa on arrival access for UAE nationals to nine airports
#
# 📰 Analyzing: 'You’re Heroes': Donald Trump welcomes freed Israeli hostages to White House; calls it an ‘honour’ to meet them
#
# 📰 Analyzing: UAE weather: Red and yellow fog alerts as visibility drops in Abu Dhabi and Dubai
#
# 📰 Analyzing: Mumbai's pigeon ban row | A growing pigeon menace
#
# 📰 Analyzing: Vande Bharat Express | Fast train on slow track
#
# 📰 Analyzing: Toxic cough syrups | Nail the culprits
#
# 📰 Analyzing: H-1B visas | How to survive the blow
#
# 📰 Analyzing: EV infra | Battling range anxiety
#
# 📰 Analyzing: Cyclone Senyar Forecast LIVE Updates: IMD issues high-wave, heavy rain alert for Andaman & Nicobar islands
#
# 📰 Analyzing: South India Weather, Politics Live Updates: South India Weather, Politics LIVE updates: ED raids former MLA’s home; Ex-TDB chief arrested in Sabarimala gold theft case
#
# 📰 Analyzing: Gold Today Rate, November 21: Check 18, 22 and 24 carat gold prices Chennai, Mumbai, Delhi, Kolkata and other cities
#
# 📰 Analyzing: News Today Live Updates, 21 November | Pune on My Plate: How city’s newer South Indian restaurants have gone beyond idli, dosa to offer reimagined fare
#
# 📰 Analyzing: JNMF unveils Nehru Archive; 100-volume ‘Selected Works’ goes online in first phase

# %%
import json
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "title": "Jaipur Girl Begged Teacher For Help \"For 45 Minutes\" Before Suicide: Report",
#     "link": "https://www.ndtv.com/india-news/jaipur-neerja-modi-school-suicide-class-4-student-probe-report-cbse-latest-news-rajasthan-9674428#publisher=newsstand",
#     "incident": {
#       "classification": "BAD",
#       "event_type": "achievement",
#       "severity": "high",
#       "deaths": 1,
#       "injured": 0,
#       "main_incident_location": "Jaipur",
#       "other_locations": [],
#       "summary": "A student in Jaipur begged her teacher for help for 45 minutes before taking her own life.",
#       "location_details": {
#         "district": "Jaipur",
#         "state": "RAJASTHAN",
#         "district_code": 110,
#         "state_code": 8
#       }
#     }
#   },
#   {
#     "title": "'Very Intense Earthquake, Building Shook For 30 Seconds': Kolkata Residents On Tremors",
#     "link": "https://www.ndtv.com/india-news/earthquake-kolkata-today-latest-news-most-intense-earthquake-of-my-life-residents-on-kolkata-tremors-9674456#publisher=newsstand",
#     "incident": {
#       "classification": "BAD",
#       "event_type": "natural disaster",
#       "severity": "high",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Kolkata",
#       "other_locations": [],
#       "summary": "Kolkata residents experienced an intense earthquake that lasted for 30 seconds.",
#       "location_details": {
#         "district": "Kolkata",
#         "state": "WEST BENGAL",
#         "district_code": 342,
#         "state_code": 19
#       }
#     }
#   },
#   {
#     "title": "5.7-Magnitude Earthquake Hits Bangladesh, Tremors Felt In Kolkata",
#     "link": "https://www.ndtv.com/india-news/strong-earthquake-tremors-felt-in-kolkata-adjoining-areas-9674406#publisher=newsstand",
#     "incident": {
#       "classification": "NEUTRAL",
#       "event_type": "natural disaster",
#       "severity": "low",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Ghorashal",
#       "other_locations": "Kolkata, Bangladesh",
#       "summary": "A 5.5-magnitude earthquake struck Bangladesh's Ghorashal area, causing mild tremors in Kolkata.",
#       "location_details": null
#     }
#   },
#   {
#     "title": "\"Stand And Greet\": New SOP For Maharashtra Officials To Welcome Politicians",
#     "link": "https://www.ndtv.com/india-news/stand-and-greet-new-sop-for-maharashtra-officials-to-welcome-politicians-9674659#publisher=newsstand",
#     "incident": {
#       "classification": "NEUTRAL",
#       "event_type": "political",
#       "severity": "low",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Maharashtra",
#       "other_locations": null,
#       "summary": "Maharashtra officials to follow new SOP to welcome politicians",
#       "location_details": {
#         "district": null,
#         "state": "MAHARASHTRA",
#         "district_code": null,
#         "state_code": 27
#       }
#     }
#   },
#   {
#     "title": "Over 200 Al Falah University Doctors, Staff Under Scanner After Delhi Blast",
#     "link": "https://www.ndtv.com/india-news/delhi-bomb-blast-al-falah-university-over-200-al-falah-university-doctors-staff-under-scanner-after-delhi-blast-9674611#publisher=newsstand",
#     "incident": {
#       "classification": "BAD",
#       "event_type": "accident",
#       "severity": "high",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Delhi",
#       "other_locations": "Blas t",
#       "summary": "Over 200 Al Falah University Doctors, Staff Under Scanner After Delhi Blast",
#       "location_details": null
#     }
#   },
#   {
#     "title": "\u2018Emotionally exhausting\u2019: Al Falah University students' kin unsure of next steps amid terror probe",
#     "link": "https://www.hindustantimes.com/india-news/emotionally-exhausting-al-falah-university-students-kin-unsure-of-next-steps-amid-terror-probe-101763701230297.html",
#     "incident": {
#       "classification": "BAD",
#       "event_type": "crime",
#       "severity": "high",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Faridabad",
#       "other_locations": [],
#       "summary": "Al Falah University of Faridabad came under scanner after a crackdown on white collar terror module led probe agencies to faculty members.",
#       "location_details": {
#         "district": "Faridabad",
#         "state": "HARYANA",
#         "district_code": 88,
#         "state_code": 6
#       }
#     }
#   },
#   {
#     "title": "Himachal man who lost his memory reunited with family after 45 years",
#     "link": "https://www.hindustantimes.com/india-news/himachal-man-who-lost-his-memory-reunited-with-family-after-45-years-101763704979209.html",
#     "incident": {
#       "classification": "GOOD",
#       "event_type": "achievement",
#       "severity": "low",
#       "deaths": 0,
#       "injured": 0,
#       "main_incident_location": null,
#       "other_locations": [],
#       "summary": "A Himachal man who lost his memory was reunited with his family after 45 years."
#     }
#   },
#   {
#     "title": "Haryana man kills sister for marrying against family's wishes, held before attacking her husband",
#     "link": "https://www.hindustantimes.com/india-news/haryana-man-kills-sister-for-marrying-against-familys-wishes-held-before-attacking-her-husband-101763704059809.html",
#     "incident": {
#       "classification": "BAD",
#       "event_type": "crime",
#       "severity": "high",
#       "deaths": 1,
#       "injured": 0,
#       "main_incident_location": "Rohtak's Kahani village",
#       "other_locations": [
#         "Haryana"
#       ],
#       "summary": "A man in Haryana killed his sister for marrying against family's wishes and was arrested before he could attack her husband.",
#       "location_details": null
#     }
#   },
#   {
#     "title": "Kolkata earthquake: Chandelier, light, water bottle shake as tremors jolt city",
#     "link": "https://www.hindustantimes.com/trending/kolkata-earthquake-chandelier-light-water-bottle-shake-as-tremors-jolt-city-101763703350477.html",
#     "incident": {
#       "classification": "NEUTRAL",
#       "event_type": "natural disaster",
#       "severity": "low",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Kolkata",
#       "other_locations": [],
#       "summary": "A mild earthquake caused tremors in Kolkata, with people capturing the moment on social media.",
#       "location_details": {
#         "district": "Kolkata",
#         "state": "WEST BENGAL",
#         "district_code": 342,
#         "state_code": 19
#       }
#     }
#   },
#   {
#     "title": "\u2018Bollywood-style beating\u2019: Assam CM after police seize drug contraband",
#     "link": "https://www.hindustantimes.com/india-news/bollywoodstyle-beating-assam-cm-after-police-seize-drug-contraband-101763703517411.html",
#     "incident": {
#       "classification": "BAD",
#       "event_type": "crime",
#       "severity": "high",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Assam",
#       "other_locations": null,
#       "summary": "Assam CM praises police for seizing large quantities of drug contraband.",
#       "location_details": {
#         "district": null,
#         "state": "ASSAM",
#         "district_code": null,
#         "state_code": 18
#       }
#     }
#   },
#   {
#     "title": "'He\u2019s frank': White House defends Trump\u2019s 'Piggy' remark on female reporter; asks media to appreciate his 'candour'",
#     "link": "https://timesofindia.indiatimes.com/world/us/hes-frank-white-house-defends-trumps-piggy-remark-on-female-reporter-asks-media-to-appreciate-his-candour/articleshow/125478988.cms",
#     "incident": {
#       "classification": "BAD",
#       "event_type": "other",
#       "severity": "low",
#       "deaths": 0,
#       "injured": 0,
#       "main_incident_location": "White House",
#       "other_locations": "India, Times",
#       "summary": "The White House defended President Trump's use of the term 'piggy' towards a female reporter, attributing it to his frankness and frustration with perceived false reporting.",
#       "location_details": null
#     }
#   },
#   {
#     "title": "UAE named as world 3rd largest humanitarian donor in 2025 with $1.46 billion in global relief",
#     "link": "https://timesofindia.indiatimes.com/world/middle-east/uae-named-as-world-3rd-largest-humanitarian-donor-in-2025-with-1-46-billion-in-global-relief/articleshow/125478341.cms",
#     "incident": {
#       "classification": "GOOD",
#       "event_type": "achievement",
#       "severity": "low",
#       "deaths": 0,
#       "injured": 0,
#       "main_incident_location": "UAE",
#       "other_locations": [],
#       "summary": "UAE recognized as the world's third-largest humanitarian donor for 2025, contributing $1.46 billion in aid.",
#       "location_details": null
#     }
#   },
#   {
#     "title": "India expands visa on arrival access for UAE nationals to nine airports",
#     "link": "https://timesofindia.indiatimes.com/world/middle-east/india-expands-visa-on-arrival-access-for-uae-nationals-to-nine-airports/articleshow/125478197.cms",
#     "incident": {
#       "classification": "GOOD",
#       "event_type": "achievement",
#       "severity": "low",
#       "deaths": 0,
#       "injured": 0,
#       "main_incident_location": "India",
#       "other_locations": [
#         "UAE",
#         "Kochi",
#         "Calicut",
#         "Ahmedabad"
#       ],
#       "summary": "India expands visa on arrival access for UAE nationals to nine airports.",
#       "location_details": null
#     }
#   },
#   {
#     "title": "'You\u2019re Heroes': Donald Trump welcomes freed Israeli hostages to White House; calls it an \u2018honour\u2019 to meet them",
#     "link": "https://timesofindia.indiatimes.com/world/us/youre-heroes-donald-trump-welcomes-freed-israeli-hostages-to-white-house-calls-it-an-honour-to-meet-them/articleshow/125478095.cms",
#     "incident": {
#       "classification": "GOOD",
#       "event_type": "achievement",
#       "severity": "low",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "White House",
#       "other_locations": "Israel",
#       "summary": "President Trump welcomed 26 freed Israeli hostages at the White House, calling them 'heroes'.",
#       "location_details": null
#     }
#   },
#   {
#     "title": "UAE weather: Red and yellow fog alerts as visibility drops in Abu Dhabi and Dubai",
#     "link": "https://timesofindia.indiatimes.com/world/middle-east/uae-weather-red-and-yellow-fog-alerts-as-visibility-drops-in-abu-dhabi-and-dubai/articleshow/125477359.cms",
#     "incident": {
#       "classification": "NEUTRAL",
#       "event_type": "natural disaster",
#       "severity": "low",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Abu Dhabi and Dubai",
#       "other_locations": "UAE",
#       "summary": "Dense fog swept across Abu Dhabi and parts of Dubai on Friday, reducing visibility below 1,000 metres in some areas.",
#       "location_details": null
#     }
#   },
#   {
#     "title": "Mumbai's pigeon ban row | A growing pigeon menace",
#     "link": "https://www.indiatoday.in/magazine/the-big-story/story/20251117-mumbais-pigeon-ban-row-a-growing-pigeon-menace-2815193-2025-11-07?utm_source=rss",
#     "incident": {
#       "classification": "NEUTRAL",
#       "event_type": "other",
#       "severity": "low",
#       "deaths": 0,
#       "injured": 0,
#       "main_incident_location": "Mumbai",
#       "other_locations": "today",
#       "summary": "Mumbai is dealing with a growing pigeon menace, leading to a ban row.",
#       "location_details": {
#         "district": "Mumbai",
#         "state": "MAHARASHTRA",
#         "district_code": 519,
#         "state_code": 27
#       }
#     }
#   },
#   {
#     "title": "Vande Bharat Express | Fast train on slow track",
#     "link": "https://www.indiatoday.in/magazine/the-big-story/story/20251103-vande-bharat-express-fast-train-on-slow-track-2807679-2025-10-24?utm_source=rss",
#     "incident": {
#       "classification": "BAD",
#       "event_type": "other",
#       "severity": "high",
#       "deaths": 0,
#       "injured": 0,
#       "main_incident_location": "India",
#       "other_locations": [
#         "India Today",
#         "S Hub"
#       ],
#       "summary": "The Vande Bharat Express is facing issues due to slow tracks, affecting its performance.",
#       "location_details": null
#     }
#   },
#   {
#     "title": "Toxic cough syrups | Nail the culprits",
#     "link": "https://www.indiatoday.in/magazine/the-big-story/story/20251020-toxic-cough-syrups-nail-the-culprits-2801069-2025-10-10?utm_source=rss",
#     "incident": {
#       "classification": "BAD",
#       "event_type": "accident",
#       "severity": "high",
#       "deaths": 68,
#       "injured": null,
#       "main_incident_location": null,
#       "other_locations": [
#         "India"
#       ],
#       "summary": "The Indian government has been criticized for its handling of the toxic cough syrup scandal, which has resulted in the deaths of at least 68 children."
#     }
#   },
#   {
#     "title": "H-1B visas | How to survive the blow",
#     "link": "https://www.indiatoday.in/magazine/the-big-story/story/20251006-h-1b-visas-how-to-survive-the-blow-2793075-2025-09-26?utm_source=rss",
#     "incident": {
#       "classification": "NEUTRAL",
#       "event_type": "other",
#       "severity": "low",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": null,
#       "other_locations": [
#         "IndiaToday",
#         "in",
#         "s hub"
#       ],
#       "summary": "The article discusses the impact of H-1B visa changes on Indians and provides tips to survive the blow."
#     }
#   },
#   {
#     "title": "EV infra | Battling range anxiety",
#     "link": "https://www.indiatoday.in/magazine/the-big-story/story/20250922-ev-infra-battling-range-anxiety-indias-electric-vehicle-infrastructure-2786202-2025-09-12?utm_source=rss",
#     "incident": {
#       "classification": "NEUTRAL",
#       "event_type": "other",
#       "severity": "low",
#       "deaths": 0,
#       "injured": 0,
#       "main_incident_location": null,
#       "other_locations": [
#         "India"
#       ],
#       "summary": "India's electric vehicle infrastructure is battling range anxiety."
#     }
#   },
#   {
#     "title": "Cyclone Senyar Forecast LIVE Updates: IMD issues high-wave, heavy rain alert for Andaman & Nicobar islands",
#     "link": "https://indianexpress.com/article/india/cyclone-senyar-live-tracker-forecast-rains-tamil-nadu-andhra-telangana-odisha-imd-alert-10377763/",
#     "incident": {
#       "classification": "NEUTRAL",
#       "event_type": "natural disaster",
#       "severity": "high",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Andaman & Nicobar islands",
#       "other_locations": [],
#       "summary": "IMD issues high-wave, heavy rain alert for Andaman & Nicobar islands due to Cyclone Senyar",
#       "location_details": {
#         "district": null,
#         "state": "ANDAMAN & NICOBAR ISLANDS",
#         "district_code": null,
#         "state_code": 35
#       }
#     }
#   },
#   {
#     "title": "South India Weather, Politics Live Updates: South India Weather, Politics LIVE updates: ED raids former MLA\u2019s home; Ex-TDB chief arrested in Sabarimala gold theft case",
#     "link": "https://indianexpress.com/article/india/south-india-news-live-updates-imd-rain-tamil-nadu-kerala-karnataka-andhra-sabarimala-gold-theft-10377724/",
#     "incident": {
#       "classification": "BAD",
#       "event_type": "crime",
#       "severity": "high",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Sabarimala",
#       "other_locations": "South India",
#       "summary": "ED raids former MLA\u2019s home; Ex-TDB chief arrested in Sabarimala gold theft case",
#       "location_details": null
#     }
#   },
#   {
#     "title": "Gold Today Rate, November 21: Check 18, 22 and 24 carat gold prices Chennai, Mumbai, Delhi, Kolkata and other cities",
#     "link": "https://indianexpress.com/article/india/gold-today-rate-november-21-check-18-22-and-24-carat-gold-prices-chennai-mumbai-delhi-kolkata-and-other-cities-10377714/",
#     "incident": {
#       "classification": "NEUTRAL",
#       "event_type": "other",
#       "severity": "low",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Chennai",
#       "other_locations": "Mumbai, Kolkata, Delhi",
#       "summary": "Gold prices are available in various cities across India.",
#       "location_details": {
#         "district": "Chennai",
#         "state": "TAMIL NADU",
#         "district_code": 603,
#         "state_code": 33
#       }
#     }
#   },
#   {
#     "title": "News Today Live Updates, 21 November | Pune on My Plate: How city\u2019s newer South Indian restaurants have gone beyond idli, dosa to offer reimagined fare",
#     "link": "https://indianexpress.com/article/india/latest-news-today-live-updates-world-india-cities-news-delhi-mumbai-bengaluru-11-21-2025-news-headlines-10377453/",
#     "incident": {
#       "classification": "NEUTRAL",
#       "event_type": "other",
#       "severity": "low",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": "Pune",
#       "other_locations": [],
#       "summary": "Pune's newer South Indian restaurants offer reimagined fare beyond idli and dosa.",
#       "location_details": {
#         "district": "Pune",
#         "state": "MAHARASHTRA",
#         "district_code": 521,
#         "state_code": 27
#       }
#     }
#   },
#   {
#     "title": "JNMF unveils Nehru Archive; 100-volume \u2018Selected Works\u2019 goes online in first phase",
#     "link": "https://indianexpress.com/article/india/jnmf-nehru-archive-selected-works-jawaharlal-nehru-online-first-phase-10377635/",
#     "incident": {
#       "classification": "GOOD",
#       "event_type": "achievement",
#       "severity": "low",
#       "deaths": null,
#       "injured": null,
#       "main_incident_location": null,
#       "other_locations": [],
#       "summary": "JNMF unveils Nehru Archive; 100-volume \u2018Selected Works\u2019 goes online in first phase"
#     }
#   }
# ]

# %%
import requests
from bs4 import BeautifulSoup

def scrape_article_hindi(url):
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/120.0.0.0 Safari/537.36"
        ),
        "Accept-Language": "hi-IN,hi;q=0.9,en;q=0.8",
        "Referer": "https://www.google.com/",
    }
    try:
        r = requests.get(url, headers=headers, timeout=10)
        if r.status_code != 200:
            print("❌ Request blocked:", r.status_code, url)
            return None
        soup = BeautifulSoup(r.text, "lxml")

        # headline
        h1 = soup.find("h1")
        title = h1.get_text(strip=True) if h1 else ""

        # body – pick up article text paragraphs
        paragraphs = soup.find_all("p")
        body = "\n".join([p.get_text(strip=True) for p in paragraphs])

        full_text = title + "\n\n" + body
        return full_text if len(full_text) > 50 else None

    except Exception as e:
        print("Error scraping:", e, url)
        return None

# %%
def chunk_text_for_ner(text, max_tokens=450):
    words = text.split()
    chunks = []
    current_chunk = []

    for word in words:
        current_chunk.append(word)
        # estimate token length approx = words * 1.3
        if len(current_chunk) > max_tokens:
            chunks.append(" ".join(current_chunk))
            current_chunk = []

    if current_chunk:
        chunks.append(" ".join(current_chunk))

    return chunks

# %%
def extract_locations(text):
    chunks = chunk_text_for_ner(text, max_tokens=400)

    all_locations = []

    for chunk in chunks:
        toks = tokenizer(chunk, return_tensors="pt", truncation=True, max_length=512)
        toks = {k: v.to(DEVICE) for k, v in toks.items()}
        with torch.no_grad():
            logits = model(**toks).logits[0]

        preds = torch.argmax(logits, dim=-1).tolist()
        tokens = tokenizer.convert_ids_to_tokens(toks["input_ids"][0])

        locations = []
        buf = ""

        for tok, p in zip(tokens, preds):
            label = id2tag[p]
            tok = tok.replace("▁", "")

            if label == "B-LOC":
                if buf:
                    locations.append(buf)
                buf = tok
            elif label == "I-LOC":
                buf += " " + tok
            else:
                if buf:
                    locations.append(buf)
                    buf = ""

        if buf:
            locations.append(buf)

        all_locations.extend(locations)

    return list(set(all_locations))

# %%
text = scrape_article_hindi(url)
locations = extract_locations(text)
incident = extract_full_incident(text)
incident
# Out:
# {'classification': 'BAD',
#  'event_type': 'crime',
#  'severity': 'high',
#  'deaths': None,
#  'injured': None,
#  'main_incident_location': 'Delhi',
#  'other_locations': ['फरीदाबाद',
#   'आजमगढ़',
#   'गुजरात',
#   'उडुपी',
#   'जयपुर',
#   'कर्नाटक',
#   'धौज',
#   'अफगानिस्तान',
#   'अहमदाबाद'],
#  'summary': 'दिल्ली ब्लास्ट के बाद अल-फलाह विश्वविद्यालय सुर्खियों में है, और एजेंसियों के रडार पर अब अल-फलाह यूनिवर्सिटी के 200 से ज्यादा डॉक्टर हैं।',
#  'location_details': None}

# %%
url = "https://www.amarujala.com/photo-gallery/delhi-ncr/delhi-blast-200-al-falah-doctors-on-radar-many-suddenly-absconded-on-day-of-bombing-2025-11-20?src=trending"

text = scrape_article_hindi(url)
print("SCRAPED TEXT PREVIEW:\n", text[:400], "\n")

locations = extract_locations(text)
print("DETECTED LOCATIONS:", locations)

incident = extract_full_incident(text)
incident
# Out:
# SCRAPED TEXT PREVIEW:
#  Delhi Blast: अल फलाह के 200 डॉक्टर रडार पर, धमाके वाले दिन कई एकाएक हुआ फरार; डॉ. उमर को लेकर एक और खुलासा
#
# मेरा शहर
#
# Link Copied
# दिल्ली बम धमाके के बाद अल-फलाह विश्वविद्यालय सुर्खियों में है। दिल्ली में 10 नवंबर को ब्लास्ट करने वाला आत्मघाती आतंकी डॉ. उमर उन नबी अल फलाह से जुड़ा पहला आतंकी नहीं था। वर्ष 2008 में अहमदाबाद, गुजरात में हुए सीरियल बम धमाकों के समय भी अल फलाह विवि का नाम आया था। अहमदा
#
# DETECTED LOCATIONS: ['फ री द ाबाद', ' ल्ली', 'आज म गढ़', 'गुजरात', 'उड ु पी', 'Hindi', 'जयपुर', 'कर्नाटक', 'Delhi', ' धौ ज', 'अफगानिस्तान', 'अम द ाबाद', 'दिल्ली', 'अहमद ाबाद']
# {'classification': 'BAD',
#  'event_type': 'crime',
#  'severity': 'high',
#  'deaths': None,
#  'injured': None,
#  'main_incident_location': 'Delhi',
#  'other_locations': ['फरीदाबाद',
#   'आजमगढ़',
#   'गुजरात',
#   'उडुपी',
#   'जयपुर',
#   'कर्नाटक',
#   'धौज',
#   'अफगानिस्तान',
#   'अहमदाबाद'],
#  'summary': 'दिल्ली ब्लास्ट के बाद अल-फलाह विश्वविद्यालय सुर्खियों में है, और एजेंसियों के रडार पर 200 से ज्यादा डॉक्टर हैं।',
#  'location_details': None}

# %%
# !zip -r /content/xlmr_location_ner.zip /content/drive/MyDrive/NER_RETRAIN -x "/content/drive/MyDrive/NER_RETRAIN/xlmr_location_ner/*"
# Out:
#   adding: content/drive/MyDrive/NER_RETRAIN/ (stored 0%)
#   adding: content/drive/MyDrive/NER_RETRAIN/Inference.ipynb (deflated 78%)
#   adding: content/drive/MyDrive/NER_RETRAIN/eng.testb (deflated 81%)
#   adding: content/drive/MyDrive/NER_RETRAIN/eng.testa (deflated 80%)
#   adding: content/drive/MyDrive/NER_RETRAIN/eng.train (deflated 80%)
#   adding: content/drive/MyDrive/NER_RETRAIN/ner.csv (deflated 79%)
#   adding: content/drive/MyDrive/NER_RETRAIN/India District (1).xlsx (deflated 16%)
#   adding: content/drive/MyDrive/NER_RETRAIN/comprehensive_indian_ner_dataset.csv (deflated 77%)
#   adding: content/drive/MyDrive/NER_RETRAIN/.ipynb_checkpoints/ (stored 0%)
#   adding: content/drive/MyDrive/NER_RETRAIN/synthetic_sample_head.csv (deflated 56%)
#   adding: content/drive/MyDrive/NER_RETRAIN/id2tag.json (deflated 51%)
#   adding: content/drive/MyDrive/NER_RETRAIN/tag2id.json (deflated 47%)
#   adding: content/drive/MyDrive/NER_RETRAIN/NER_RETRAIN.ipynb (deflated 81%)

# %%
from google.colab import files
files.download('/content/drive/MyDrive/NER_RETRAIN')
